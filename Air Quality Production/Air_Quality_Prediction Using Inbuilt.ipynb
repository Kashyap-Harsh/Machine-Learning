# %% [markdown]
# # **Air Quality Prediction Using In built Library**

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
model= LinearRegression()

# %%
Train=pd.read_csv("Train.csv")
Test_X=pd.read_csv("Test.csv")

# %%
Train
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5      target
# 0      0.293416  -0.945599  -0.421105   0.406816   0.525662  -82.154667
# 1     -0.836084  -0.189228  -0.776403  -1.053831   0.597997  -48.897960
# 2      0.236425   0.132836  -0.147723   0.699854  -0.187364   77.270371
# 3      0.175312   0.143194  -0.581111  -0.122107  -1.292168   -2.988581
# 4     -1.693011   0.542712  -2.798729  -0.686723   1.244077  -37.596722
# ...         ...        ...        ...        ...        ...         ...
# 1595  -0.274961  -0.820634  -0.757173  -0.147555  -0.307149  -80.110012
# 1596  -0.076099   0.255257   0.290054   1.796036   0.340350  118.315601
# 1597   1.044177  -0.899206   1.730399  -1.871057   0.442520 -107.510508
# 1598  -1.269173  -0.005052   1.857669  -1.080365   0.736334  -47.341558
# 1599  -1.884000  -0.849427  -1.452270   0.488613   1.459576 -115.939003
#
# [1600 rows x 6 columns]

# %%
Train_X=Train.iloc[:,0:-1]
Train_Y=Train.iloc[:,-1]

# %%
Train_X=np.array(Train_X)
Train_Y=np.array(Train_Y)
Test_X=np.array(Test_X)
Test_Y=np.array(Test_Y)

# %%
def Normaliser(X):
  m,n=X.shape
  for i in range(n):
    mean=np.mean(X[:,i])
    std=np.std(X[:,i])
    for j in range(m):
      X[j,i]=(X[j,i]-mean)/std
  return X

# %%
#Normalise datset
Train_X=Normaliser(Train_X)

# %%
Train_X[:,0].shape, Train_Y.shape
# Out:
# ((1600,), (1600,))

# %%
plt.style.use('seaborn')
plt.subplot(1,2,1)
plt.scatter(Train_X[:,0],Train_Y,color='red')
plt.title("Feature 1 vs Result")
plt.xlabel("Feature 1")
plt.ylabel("Result")
plt.show()

plt.subplot(1,2,2)
plt.scatter(Train_X[:,1],Train_Y,color='green')
plt.title("Feature 2 vs Result")
plt.xlabel("Feature 2")
plt.ylabel("Result")
plt.show()

plt.subplot(1,2,2)
plt.scatter(Train_X[:,2],Train_Y,color='blue')
plt.title("Feature 3 vs Result")
plt.xlabel("Feature 3")
plt.ylabel("Result")
plt.show()

plt.subplot(1,3,2)
plt.scatter(Train_X[:,3],Train_Y,color='brown')
plt.title("Feature 4 vs Result")
plt.xlabel("Feature 4")
plt.ylabel("Result")
plt.show()

plt.subplot(2,3,2)
plt.scatter(Train_X[:,4],Train_Y,color='yellow')
plt.title("Feature 5 vs Result")
plt.xlabel("Feature 5")
plt.ylabel("Result")
plt.show()

# %%
model.fit(Train_X,Train_Y)
# Out:
# LinearRegression()

# %%
print("Score of the Model is "+str(np.round((model.score(Train_X,Train_Y)),2)*100)+" %")
# Out:
# Score of the Model is 97.0 %

# %%
YPredicted=model.predict(Test_X)

# %%
YPredicted.shape
# Out:
# (400,)

# %%
print("Predicted Values = ", YPredicted)
# Out:
# Predicted Values =  [ 115.77102898  115.92990429  -22.04992841  -46.46177563  -97.38666201
#   -45.56987741  -78.52398889   22.58739877  171.63277442  171.9537867
#  -106.75969314  -21.49855929   -5.63390495  121.63043509   40.28362836
#    44.00324667 -189.69389728   22.3692861     9.5501096   135.95267689
#    64.00495782  -63.43853793 -109.97163918   -9.01511801  -59.44971651
#    11.48620265   29.1280994   107.30045716   22.78080326  -28.18622904
#   110.76411724  -46.55346264  215.64913943  -15.33507724 -230.44255151
#   152.67119041   -1.93505646   11.72826448 -310.39642186   77.20443873
#   -82.46548856 -208.50076697 -239.13473922  132.30133266  -76.6368075
#   104.29387037   -4.87459801   19.79798391  -98.55955087  -28.62096401
#     9.87429842 -176.20331178   64.86643677  -97.39953483 -108.60150727
#  -155.45277636   59.65923743  109.33942529  -75.46959415   39.70488966
#    40.18602775  -51.83657961  163.84530539   43.78383572   56.19441912
# ...

# %%
plt.style.use('seaborn')
plt.subplot(1,2,1)
plt.scatter(Test_X[:,0],YPredicted,color='red')
plt.title("Feature 1 vs Predicted Result")
plt.xlabel("Feature 1")
plt.ylabel("Result")
plt.show()

plt.subplot(1,2,2)
plt.scatter(Test_X[:,1],YPredicted,color='green')
plt.title("Feature 2 vs Predicted Result")
plt.xlabel("Feature 2")
plt.ylabel("Result")
plt.show()

plt.subplot(1,2,2)
plt.scatter(Test_X[:,2],YPredicted,color='blue')
plt.title("Feature 3 vs Predicted Result")
plt.xlabel("Feature 3")
plt.ylabel("Result")
plt.show()

plt.subplot(1,3,2)
plt.scatter(Test_X[:,3],YPredicted,color='brown')
plt.title("Feature 4 vs Predicted Result")
plt.xlabel("Feature 4")
plt.ylabel("Result")
plt.show()

plt.subplot(2,3,2)
plt.scatter(Test_X[:,4],YPredicted,color='yellow')
plt.title("Feature 5 vs Predicted Result")
plt.xlabel("Feature 5")
plt.ylabel("Result")
plt.show()
