# %% [markdown]
# ###**MOVIE RECOMMENDATION SYSTEM**

# %% [markdown]
# Importing the Data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing Dataset - [Download from here](https://files.grouplens.org/datasets/movielens/ml-100k.zip)

# %%
column=["user_id","item_id","rating","timestamp"]
rating=pd.read_csv("u.data",sep='\t',names=column)

# %%
rating.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
rating.shape
# Out:
# (100000, 4)

# %%
rating['user_id'].nunique()
# Out:
# 943

# %%
movie=pd.read_csv("u.item",sep="\|",header=None)

# %%
movie.head()
# Out:
#    0                  1            2   3   ... 20  21  22  23
# 0   1   Toy Story (1995)  01-Jan-1995 NaN  ...  0   0   0   0
# 1   2   GoldenEye (1995)  01-Jan-1995 NaN  ...  0   1   0   0
# 2   3  Four Rooms (1995)  01-Jan-1995 NaN  ...  0   1   0   0
# 3   4  Get Shorty (1995)  01-Jan-1995 NaN  ...  0   0   0   0
# 4   5     Copycat (1995)  01-Jan-1995 NaN  ...  0   1   0   0
#
# [5 rows x 24 columns]

# %% [markdown]
# Data Preprocessing

# %%
movie=movie[[0,1]]

movie.columns=["item_id","Title"]
movie.head()
# Out:
#    item_id              Title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
#Merge both files
df=pd.merge(rating,movie,on="item_id")
df.head()
# Out:
#    user_id  item_id  rating  timestamp         Title
# 0      196      242       3  881250949  Kolya (1996)
# 1       63      242       3  875747190  Kolya (1996)
# 2      226      242       5  883888671  Kolya (1996)
# 3      154      242       3  879138235  Kolya (1996)
# 4      306      242       5  876503793  Kolya (1996)

# %% [markdown]
# Exploratory Data Analysis

# %%
sns.set_style('white')

# %%
df.groupby('Title').mean()['rating'].sort_values(ascending=False).head()
# Out:
# Title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('Title').count()['rating'].sort_values(ascending=False)
# Out:
# Title
# Star Wars (1977)                              583
# Contact (1997)                                509
# Fargo (1996)                                  508
# Return of the Jedi (1983)                     507
# Liar Liar (1997)                              485
#                                              ...
# Man from Down Under, The (1943)                 1
# Marlene Dietrich: Shadow and Light (1996)       1
# Mat' i syn (1997)                               1
# Mille bolle blu (1993)                          1
# � k�ldum klaka (Cold Fever) (1994)              1
# Name: rating, Length: 1664, dtype: int64

# %%
ratings=pd.DataFrame(df.groupby('Title').mean()['rating'])
ratings['No.']=pd.DataFrame(df.groupby('Title').count()['rating'])
ratings
# Out:
#                                          rating  No.
# Title
# 'Til There Was You (1997)              2.333333    9
# 1-900 (1994)                           2.600000    5
# 101 Dalmatians (1996)                  2.908257  109
# 12 Angry Men (1957)                    4.344000  125
# 187 (1997)                             3.024390   41
# ...                                         ...  ...
# Young Guns II (1990)                   2.772727   44
# Young Poisoner's Handbook, The (1995)  3.341463   41
# Zeus and Roxanne (1997)                2.166667    6
# unknown                                3.444444    9
# � k�ldum klaka (Cold Fever) (1994)     3.000000    1
#
# [1664 rows x 2 columns]

# %%
ratings.sort_values(by='rating',ascending=False)
# Out:
#                                               rating  No.
# Title
# They Made Me a Criminal (1939)                   5.0    1
# Marlene Dietrich: Shadow and Light (1996)        5.0    1
# Saint of Fort Washington, The (1993)             5.0    2
# Someone Else's America (1995)                    5.0    1
# Star Kid (1997)                                  5.0    3
# ...                                              ...  ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)     1.0    1
# King of New York (1990)                          1.0    1
# Touki Bouki (Journey of the Hyena) (1973)        1.0    1
# Bloody Child, The (1996)                         1.0    1
# Crude Oasis, The (1995)                          1.0    1
#
# [1664 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.hist(ratings["No."])
plt.show()

# %%
plt.hist(ratings['rating'])
plt.show()

# %%
sns.jointplot(x='rating',y='No.',data=ratings,alpha=0.5)

# %% [markdown]
# ### **MOVIE RECOMMENDATION SYSTEM**

# %%
df
# Out:
#        user_id  ...                                              Title
# 0          196  ...                                       Kolya (1996)
# 1           63  ...                                       Kolya (1996)
# 2          226  ...                                       Kolya (1996)
# 3          154  ...                                       Kolya (1996)
# 4          306  ...                                       Kolya (1996)
# ...        ...  ...                                                ...
# 99995      840  ...                                  Mamma Roma (1962)
# 99996      655  ...                             Eighth Day, The (1996)
# 99997      655  ...                                  Girls Town (1996)
# 99998      655  ...  Silence of the Palace, The (Saimt el Qusur) (1...
# 99999      655  ...                                    Dadetown (1995)
#
# [100000 rows x 5 columns]

# %%
moviemat=df.pivot_table(index="user_id",columns="Title",values="rating")
moviemat
# Out:
# Title    'Til There Was You (1997)  ...  � k�ldum klaka (Cold Fever) (1994)
# user_id                             ...
# 1                              NaN  ...                                 NaN
# 2                              NaN  ...                                 NaN
# 3                              NaN  ...                                 NaN
# 4                              NaN  ...                                 NaN
# 5                              NaN  ...                                 NaN
# ...                            ...  ...                                 ...
# 939                            NaN  ...                                 NaN
# 940                            NaN  ...                                 NaN
# 941                            NaN  ...                                 NaN
# 942                            NaN  ...                                 NaN
# 943                            NaN  ...                                 NaN
#
# ...

# %% [markdown]
# Prediction

# %%
def predict (movie):
  X=moviemat[movie]
  similarToX=moviemat.corrwith(X)
  dfX=pd.DataFrame(similarToX,columns=["Correlation"])
  dfX.dropna(inplace=True)
  #dfX=dfX.sort_values(by='Correlation',ascending=False)
  dfX=dfX.join(ratings["No."])
  #dfStarWars.head(10)
  dfX=dfX[dfX["No."]>100].sort_values('Correlation',ascending=False)
  print("Most Likely Movies to be suggsted to you on your prefernece of "+movie+" is : ")
  k=pd.DataFrame(dfX.head(10).index,index=None,columns=["Title"])
  #print(dfX.head(10).index)
  #print(dfX.shape)
  print(k)
# Out:
# Most Likely Movies to be suggsted to you on your prefernece of Star Wars (1977) is :
#                                                Title
# 0                                   Star Wars (1977)
# 1                    Empire Strikes Back, The (1980)
# 2                          Return of the Jedi (1983)
# 3                     Raiders of the Lost Ark (1981)
# 4  Austin Powers: International Man of Mystery (1...
# 5                                  Sting, The (1973)
# 6          Indiana Jones and the Last Crusade (1989)
# 7                                   Pinocchio (1940)
# 8                            Frighteners, The (1996)
# 9                           L.A. Confidential (1997)

# %%
#predict("Star Wars (1977)")

movie=input("Enter movie you like : ")
try:
  predict(movie)
except:
  print("Movie not found")
# Out:
# Enter movie you like : Star Wars (1977)
# Most Likely Movies to be suggsted to you on your prefernece of Star Wars (1977) is :
#                                                Title
# 0                                   Star Wars (1977)
# 1                    Empire Strikes Back, The (1980)
# 2                          Return of the Jedi (1983)
# 3                     Raiders of the Lost Ark (1981)
# 4  Austin Powers: International Man of Mystery (1...
# 5                                  Sting, The (1973)
# 6          Indiana Jones and the Last Crusade (1989)
# 7                                   Pinocchio (1940)
# 8                            Frighteners, The (1996)
# 9                           L.A. Confidential (1997)

# %% [markdown]
# Thank You
